# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
market_data_scaled = StandardScaler().fit_transform(df_market_data)
print(market_data_scaled)
# Out:
# [[ 5.08529366e-01  4.93193071e-01  7.72200433e-01  2.35459633e-01
#   -6.74950963e-02 -3.55953481e-01 -2.51636882e-01]
#  [ 1.85445894e-01  9.34445040e-01  5.58692121e-01 -5.43409317e-02
#   -2.73482725e-01 -1.15759474e-01 -1.99352110e-01]
#  [ 2.17739616e-02 -7.06336853e-01 -2.16804207e-02 -6.10301536e-02
#    8.00452481e-03 -5.50246924e-01 -2.82060506e-01]
#  [-4.07643829e-02 -8.10928066e-01  2.49457974e-01 -5.03879651e-02
#   -3.73164019e-01 -4.58258816e-01 -2.95546142e-01]
#  [ 1.19303608e+00  2.00095907e+00  1.76061001e+00  5.45842065e-01
#   -2.91202870e-01 -4.99847761e-01 -2.70316950e-01]
#  [ 8.91870708e-01  1.32729453e+00  8.00214184e-01 -5.71478992e-02
#    7.78653106e-01 -1.88231917e-01 -2.25532605e-01]
#  [ 1.13972400e-02  2.57225091e+00  1.10164693e+00 -4.90495415e-01
#   -9.31954023e-01  3.87758986e-01 -1.82843995e-02]
#  [ 1.02529802e-01  1.50800146e+00  6.48885061e-01  3.28959245e-01
#   -4.86348899e-01  6.50796233e-02 -1.55428416e-01]
# ...

# %%
# Create a DataFrame with the scaled data
df_scaled_data = pd.DataFrame(market_data_scaled, columns=df_market_data.columns)
#df_scaled_data

# Copy the crypto names from the original data
df_scaled_data['coin_id'] = df_market_data.index

# Set the coinid column as index
df_scaled_data = df_scaled_data.set_index('coin_id')

# Display sample data
df_scaled_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    model = KMeans(n_clusters=i, n_init=10)
    model.fit(df_scaled_data)
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k, 'inertia':inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow_data = pd.DataFrame(elbow_data)
df_elbow_data
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  195.820218
# 2   3  123.190482
# 3   4   79.022435
# 4   5   65.122199
# 5   6   56.168712
# 6   7   43.375876
# 7   8   37.259125
# 8   9   32.825450
# 9  10   28.491724

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_k = df_elbow_data.hvplot.line(
    x='k',
    y='inertia',
    title='Elbow Curve',
    xticks=k
)
elbow_k
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** The choice is subjective, possibly 3 or 4.
# Best practice would be to try both and see which one provides the more concise clusters.

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=1, n_init='auto')
#model = KMeans(n_clusters=3, random_state=1, n_init='auto')

# %%
# Fit the K-Means model using the scaled data
model.fit(df_scaled_data)
# Out:
# KMeans(n_clusters=4, n_init='auto', random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
cluster_labels = model.predict(df_scaled_data)

# Print the resulting array of cluster values.
print(cluster_labels)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 3 2 0 0 1
#  0 0 0 0]

# %%
# Create a copy of the DataFrame
df_scaled_data_predict = df_scaled_data.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
df_scaled_data_predict['cluster'] = model.labels_

# Display sample data
df_scaled_data_predict.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
clusters_k = df_scaled_data_predict.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by='cluster',
    hover_cols='coin_id'
)
clusters_k
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
pca_data = pca.fit_transform(df_scaled_data)
df_pca = pd.DataFrame(pca_data, columns=['PC1', 'PC2', 'PC3'])

# View the first five rows of the DataFrame. 
df_pca.head(5)
# Out:
#         PC1       PC2       PC3
# 0 -0.600667  0.842760  0.461595
# 1 -0.458261  0.458466  0.952877
# 2 -0.433070 -0.168126 -0.641752
# 3 -0.471835 -0.222660 -0.479053
# 4 -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** Total explained variance is 89.5% which means that these 3 principal components
# represent a significant portion of the variability in the dataset.

# %%
# Create a new DataFrame with the PCA data.

# Creating a DataFrame with the PCA data
pca_data_df = pd.DataFrame(
    pca_data,
    columns=['PC1', 'PC2', 'PC3']
)

#pca_data_df

# Copy the crypto names from the original data
pca_data_df['coin_id'] = df_market_data.index

# Set the coinid column as index
pca_data_df.set_index('coin_id', inplace=True)

# Display sample data
pca_data_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    k_model = KMeans(n_clusters=i, random_state=1, n_init=10)
    k_model.fit(pca_data_df)
    inertia.append(k_model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_new = {'k': k, 'interia': inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow_new = pd.DataFrame(elbow_data_new)
df_elbow_new.head()
# Out:
#    k     interia
# 0  1  256.874086
# 1  2  165.901994
# 2  3   93.774626
# 3  4   49.665497
# 4  5   38.072792

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_pca = df_elbow_new.hvplot.line(
    x='k',
    y='interia',
    title='Elbow Curve',
    xticks=k
)
elbow_pca
# Out:
# :Curve   [k]   (interia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** Again the best value for k is 3 or possibly 4.
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** There is a more distinct change in the elbow curve using the PCA data vs the original.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=1, n_init=10)

# %%
# Fit the K-Means model using the PCA data
model.fit(pca_data)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
clusters = model.predict(pca_data)
# Print the resulting array of cluster values.
print(clusters)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 3 2 0 0 1
#  0 0 0 0]

# %%
# Create a copy of the DataFrame with the PCA data
df_pca_copy = pca_data_df.copy()

# Add a new column to the DataFrame with the predicted clusters
df_pca_copy['cluster'] = clusters

# Display sample data
df_pca_copy.head()
# Out:
#                    PC1       PC2       PC3  cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595        2
# ethereum     -0.458261  0.458466  0.952877        2
# tether       -0.433070 -0.168126 -0.641752        0
# ripple       -0.471835 -0.222660 -0.479053        0
# bitcoin-cash -1.157800  2.041209  1.859715        2

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
clusters_pca = df_pca_copy.hvplot.scatter(
    x='PC1',
    y='PC2',
    by='cluster',
    hover_cols='coin_id'
)
clusters_pca
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
elbow_k + elbow_pca
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (interia)

# %%
# Composite plot to contrast the clusters
clusters_k + clusters_pca
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** The PCA reduced the dimensionality of the data, making more disctint and compact clusters. Both scatter plots have the weird cluster 3 outlier, which bears more analysis. Using 3 clusters as shown below does not provide an accurate clustering of the data, putting most of the PCA data into cluster 0 and does not provide clear clustering using the original data.

# %%
# model = KMeans(n_clusters=3, random_state=1, n_init='auto')
# model.fit(df_scaled_data)
# cluster_labels = model.predict(df_scaled_data)
# df_scaled_data_predict = df_scaled_data.copy() 
# df_scaled_data_predict['cluster'] = model.labels_
# clusters_k3 = df_scaled_data_predict.hvplot.scatter(
#     x="price_change_percentage_24h",
#     y="price_change_percentage_7d",
#     by='cluster',
#     hover_cols='coin_id'
# )

# clusters_k3
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %%
# model = KMeans(n_clusters=3, random_state=1, n_init=10)
# model.fit(pca_data)
# clusters = model.predict(pca_data)
# df_pca_copy = pca_data_df.copy()
# df_pca_copy['cluster'] = clusters
# clusters_pca3 = df_pca_copy.hvplot.scatter(
#     x='PC1',
#     y='PC2',
#     by='cluster',
#     hover_cols='coin_id'
# )
# clusters_pca3
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %%
#clusters_k3 + clusters_pca3
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster]
#       :Scatter   [PC1]   (PC2,coin_id)
